# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinWang676/Bark-Voice-Cloning/blob/main/notebooks/CosyVoice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 一键运行 CosyVoice
# !git clone --recursive https://github.com/KevinWang676/CosyVoice.git
# %cd CosyVoice
# !pip install -r requirements.txt
# !mkdir -p pretrained_models
# !git clone https://www.modelscope.cn/iic/CosyVoice-300M.git pretrained_models/CosyVoice-300M
# !export PYTHONPATH=third_party/Matcha-TTS
# !python3 webui_colab.py
